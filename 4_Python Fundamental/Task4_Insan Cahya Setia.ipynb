# %%
import pandas as pd
import numpy as np
import math as mt

# %% [markdown]
# ## 1. Buat Kalkulator Luas

# %%
def Kalkulator_luas(luas, panjang, lebar):
    luas = luas.lower()
    
    if luas == 'bujur sangkar':
        luas_BujurSangkar = panjang * lebar
        print('Luas {} adalah {} cm^2'.format(luas, luas_BujurSangkar))
    
    elif luas == 'segitiga':
        luas_Segitiga = 0.5 * lebar * panjang
        print('Luas {} adalah {} cm^2'.format(luas, luas_Segitiga))
    
    elif luas == 'jajar genjang':
        luas_JajarGenjang = lebar * panjang
        print('Luas {} adalah {} cm^2'.format(luas, luas_JajarGenjang))
    
    else:
        print('Masukkan luas dengan benar')

# %%
def Luas_trapesium(a, b, t):
        luas_Trapesium = 0.5 * (a + b) * t
        print('Luas Trapesium adalah {} cm^2'.format(luas_Trapesium))

# %%
Kalkulator_luas('Bujur Sangkar', 4, 3)
# Out:
# Luas bujur sangkar adalah 12 cm^2

# %%
Luas_trapesium(3, 5, 4)
# Out:
# Luas Trapesium adalah 16.0 cm^2

# %% [markdown]
# ## 2. Buatlah 1 function tanpa parameter dan terdapat 1 variable, dimana kamu melakukan logaritma pada variabel tersebut

# %%
def logaritma():
    angka = int(input('Masukkan angka '))
    hasil = mt.log(angka)
    return 'Logaritma dari {} adalah {}'.format(angka, hasil)

# %%
logaritma()
# Out:
# Masukkan angka 43
# 'Logaritma dari 43 adalah 3.7612001156935624'

# %% [markdown]
# ## Data Banking

# %%
banking = pd.read_csv('Banking.csv')
banking.head()
# Out:
#    age          job  marital          education  default housing loan  \
# 0   44  blue-collar  married           basic.4y  unknown     yes   no
# 1   53   technician  married            unknown       no      no   no
# 2   28   management   single  university.degree       no     yes   no
# 3   39     services  married        high.school       no      no   no
# 4   55      retired  married           basic.4y       no     yes   no
#
#     contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0  cellular   aug         thu  ...         1    999         0  nonexistent
# 1  cellular   nov         fri  ...         1    999         0  nonexistent
# 2  cellular   jun         thu  ...         3      6         2      success
# 3  cellular   apr         fri  ...         2    999         0  nonexistent
# 4  cellular   aug         fri  ...         1      3         1      success
#
#   emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  nr_employed  y
# ...

# %%
banking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp_var_rate    41188 non-null  float64
#  16  cons_price_idx  41188 non-null  float64
# ...

# %%
# Create list
col_status = []

# Define looping for status column
for x, col in banking.iterrows():
    if col['job'] == 'management':
        if col['education'] == 'university.degree':
            if col['duration'] < 150:
                status = 'rich'
            else:
                status = 'unknown'
        else:
            status = 'unknown'
            
    elif col['job'] == 'technician':
        if col['education'] == 'university.degree':
            if col['duration'] >= 150 & col['duration'] <= 200:
                status = 'middle'
            else:
                status = 'unknown'
        else:
            status = 'unknown'
    
    elif col['job'] == 'blue-collar':
        if col['education'] == 'basic.4y' or col['education'] == 'basic.6y' or col['education'] == 'basic.9y':
            if col['duration'] >200:
                status = 'middle'
            else:
                status = 'unknown'
        else:
            status = 'unknown'
    else:
        status = 'unknown'
    
    col_status.append(status)
    
    
banking['status'] = col_status

# %%
banking.head(20)
# Out:
#     age          job   marital          education  default housing loan  \
# 0    44  blue-collar   married           basic.4y  unknown     yes   no
# 1    53   technician   married            unknown       no      no   no
# 2    28   management    single  university.degree       no     yes   no
# 3    39     services   married        high.school       no      no   no
# 4    55      retired   married           basic.4y       no     yes   no
# 5    30   management  divorced           basic.4y       no     yes   no
# 6    37  blue-collar   married           basic.4y       no     yes   no
# 7    39  blue-collar  divorced           basic.9y       no     yes   no
# 8    36       admin.   married  university.degree       no      no   no
# 9    27  blue-collar    single           basic.4y       no     yes   no
# 10   34    housemaid    single  university.degree       no      no   no
# 11   41   management   married  university.degree       no     yes   no
# ...

# %% [markdown]
# ## 4.Buatlah conditional statement untuk menentukan apakah suatu bilangan itu positif, negatif, atau netral. Buatlah dalam 2 bentuk, bentuk normal if, elif... (a = -24, b=10, c= 0).

# %%
a = -24
b = 10 
c = 0

# Bentuk pertama
if a < 0:
    print('Angka {} adalah bilangan negatif'.format(a))

if a == 0:
    print('Angka {} adalah bilangan netral'.format(a))
    
if a > 0:
    print('Angka {} adalah bilangan positif'.format(a))
    
    
# Bentuk kedua
if b < 0:
    print('Angka {} adalah bilangan negatif'.format(b))
elif b == 0:
    print('Angka {} adalah bilangan netral'.format(b))
else:
    print('Angka {} adalah bilangan positif'.format(b))
# Out:
# Angka -24 adalah bilangan negatif
# Angka 10 adalah bilangan positif

# %%
list_angka = [1,2,6,9, 15,18, 20 ,21, 23, 27, 32, 39]
jumlah_item = []

for i in list_angka:
    
    if i % 2 != 0:
        if i % 3 != 0:
            print('{} adalah bilangan ganjil dan tidak habis dibagi 3'.format(i))
            jumlah_item.append(i)     
        else:
            print('{} adalah bilangan ganjil dan habis dibagi 3'.format(i))
    
    else:
        print('{} adalah bilangan genap'.format(i))

print('\n\nBilangan ganjil dan tidak habis dibagi tiga ada {} angka yaitu {}'.format(len(jumlah_item), jumlah_item))
# Out:
# 1 adalah bilangan ganjil dan tidak habis dibagi 3
# 2 adalah bilangan genap
# 6 adalah bilangan genap
# 9 adalah bilangan ganjil dan habis dibagi 3
# 15 adalah bilangan ganjil dan habis dibagi 3
# 18 adalah bilangan genap
# 20 adalah bilangan genap
# 21 adalah bilangan ganjil dan habis dibagi 3
# 23 adalah bilangan ganjil dan tidak habis dibagi 3
# 27 adalah bilangan ganjil dan habis dibagi 3
# 32 adalah bilangan genap
# 39 adalah bilangan ganjil dan habis dibagi 3
#
#
# Bilangan ganjil dan tidak habis dibagi tiga ada 2 angka yaitu [1, 23]
